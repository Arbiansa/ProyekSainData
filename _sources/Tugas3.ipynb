# %% [markdown]
# # Tugas 3 - Crawling Data Berita Online

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
#agent user : supaya web server menampilkan konten yang dimiliki sesuai dengan OS yang kita gunakan, jadi web server tau browser dan OS yang kita gunakan
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

# %%
#membuat function scraping data web
def scrape_detik(page):
  global hades  
  data = []
  for p in range(1,page+1):
    url = f"https://www.detik.com/search/searchall?query=pemilu+2024&siteid=2&sortby=time&page={p}"
    request =  req.get(url,hades).text
    #var bs yang menyimpan data request
    soup = bs(request, 'lxml')
    news_list = soup.find('div', 'list media_rows list-berita')
    news_article = news_list.find_all('article')
    for x in news_article:
      link=x.find_all('h2')
      link = [ele.text.strip() for ele in link]
      content=x.find_all('p')
      content = [ele.text.strip() for ele in content]
      data.append([link[0],content[0]])
  return data

news=scrape_detik(7)
news_result = pd.DataFrame(news,columns =['Judul','Isi'])
news_result
# Out:
#                                                 Judul  \
# 0   Partai Gelora Pede Jabar Jadi Lumbung Suara di...
# 1   Anies Dukung Sistem Pemilu Terbuka: Lebih Baik...
# 2   Ketua DPP Golkar Tolak Sistem Coblos Partai: B...
# 3   Bupati Kendal Dico Temui Gibran di Solo, Kaget...
# 4   Projo Beri Selamat JoMan Dukung Prabowo di Pil...
# ..                                                ...
# 58  Demokrat: Maklum Survei NasDem Naik di Litbang...
# 59  Cak Imin: Kalau Putusan MK Pemilu Tertutup, Ne...
# 60  Pantarlih Mulai Lakukan Coklit Daftar Pemilih ...
# 61  Adu Perspektif: Anies Vs Prabowo, Siapa Bisa R...
# 62  Waketum PKB: Jangan Sampai PKB Kayak Partai Ij...
#
#                                                   Isi
# 0   Partai Gelora Indonesia optimistis Jawa Barat ...
# 1   Anies Baswedan mendukung sistem coblos caleg a...
# 2   Ketua DPP Golkar Dave Laksono menegaskan parta...
# 3   Bupati Kendal Dico Ganinduto bertemu dengan Wa...
# 4   Relawan Pro Jokowi (Projo) memberikan selamat ...
# ..                                                ...
# 58  Elektoral NasDem naik drastis di survei Litban...
# 59  Cak Imin memendam kekhawatiran jika sistem pem...
# 60  Pantarlih mulai melakukan proses pencocokan da...
# 61  Di Indonesia, suara kalangan islam konservatif...
# 62  Jazilul mengungkit partai lain yang berwarna h...
#
# [63 rows x 2 columns]

# %%
news_result.to_csv('news.csv')
