# %% [markdown]
# # Tugas 3 - Crawling Data Berita Online

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
#agent user : supaya web server menampilkan konten yang dimiliki sesuai dengan OS yang kita gunakan, jadi web server tau browser dan OS yang kita gunakan
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

# %%
#membuat function scraping data web
def scrape_detik(page):
  global hades  
  data = []
  for p in range(1,page+1):
    url = f"https://www.detik.com/search/searchall?query=pemilu+2024&siteid=2&sortby=time&page={p}"
    request =  req.get(url,hades).text
    #var bs yang menyimpan data request
    soup = bs(request, 'lxml')
    news_list = soup.find('div', 'list media_rows list-berita')
    news_article = news_list.find_all('article')
    for x in news_article:
      link=x.find_all('h2')
      link = [ele.text.strip() for ele in link]
      content=x.find_all('p')
      content = [ele.text.strip() for ele in content]
      data.append([link[0],content[0]])
  return data

news=scrape_detik(7)
news_result = pd.DataFrame(news,columns =['Judul','Isi'])
news_result
# Out:
#                                                 Judul  \
# 0   RK Jadi Capres Alternatif Populer, Pengamat: S...
# 1   Gus Muhaimin Ingin Kebudayaan Jadi Panglima Pe...
# 2   Sudirman Said soal Anies Merosot di Survei Kom...
# 3   Jabar Hari Ini: Hukuman Lebih Berat untuk Doni...
# 4   Sudirman Said: Anies Perlu Waktu dan Ketenanga...
# ..                                                ...
# 58  Cak Imin soal Capres-cawapres 2024: Semua Stuc...
# 59  PKS Tak Iri Survei NasDem Naik di Litbang Komp...
# 60   PKB Umumkan Menaker Ida Fauziyah Maju Caleg 2024
# 61  Cak Imin Belum Terpikir Sama Sekali Berpasanga...
# 62  PPP Heran Waketum PKB Banding-bandingkan Kursi...
#
#                                                   Isi
# 0   Ridwan Kamil jadi capres alternatif berdasarka...
# 1   Ketua Umum PKB Abdul Muhaimin Iskandar (Gus Mu...
# 2   Elektabilitas Anies berada di bawah Ganjar dan...
# 3   Ragam peristiwa terjadi di Jabar hari ini, Rab...
# 4   Juru Bicara Anies Baswedan, Sudirman Said meny...
# ..                                                ...
# 58  Ketua Umum PKB Cak Imin bicara soal perkembang...
# 59  Elektabilitas PKS dan Demokrat turun di survei...
# 60  Menaker Ida Fauziyah akan dicalonkan oleh PKB ...
# 61  Waketum PKB Jazilul berharap Cak Imin jadi cap...
# 62  PPP mengaku heran dengan sikap Waketum PKB Jaz...
#
# [63 rows x 2 columns]

# %%
news_result.to_csv('news.csv')
